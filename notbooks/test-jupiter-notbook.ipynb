# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 10)

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
pd.DataFrame(df)
# Out:
#        School  Women  Men  Gap
# 0         MIT     94  152   58
# 1    Stanford     96  151   55
# 2     Harvard    112  165   53
# 3      U.Penn     92  141   49
# 4   Princeton     90  137   47
# ..        ...    ...  ...  ...
# 16      Brown     72   92   20
# 17   Berkeley     71   88   17
# 18      Emory     68   82   14
# 19       UCLA     64   78   14
# 20      SoCal     72   81    9
#
# [21 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Documents\Programmation\Python\Test\test-jupiter-notbook.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell:/d%3A/Documents/Programmation/Python/Test/test-jupiter-notbook.ipynb#ch0000002?line=0'>1</a> bars = [go.Bar(x=df.School, y=df.Gap)]
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/Programmation/Python/Test/test-jupiter-notbook.ipynb#ch0000002?line=1'>2</a> iplot(bars)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\offline\offline.py:392, in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=386'>387</a> post_script = build_save_image_post_script(
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=387'>388</a>     image, filename, image_height, image_width, "iplot"
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=388'>389</a> )
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=390'>391</a> # Show figure
# --> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=391'>392</a> pio.show(
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=392'>393</a>     figure,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=393'>394</a>     validate=validate,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=394'>395</a>     config=config,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=395'>396</a>     auto_play=auto_play,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=396'>397</a>     post_script=post_script,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=397'>398</a>     animation_opts=animation_opts,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/offline/offline.py?line=398'>399</a> )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\io\_renderers.py:397, in show(fig, renderer, validate, **kwargs)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=391'>392</a>         raise ValueError(
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=392'>393</a>             "Mime type rendering requires ipython but it is not installed"
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=393'>394</a>         )
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=395'>396</a>     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=396'>397</a>         raise ValueError(
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=397'>398</a>             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=398'>399</a>         )
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=400'>401</a>     ipython_display.display(bundle, raw=True)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/io/_renderers.py?line=402'>403</a> # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
